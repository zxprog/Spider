# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt 
import numpy as np
import matplotlib.image as mpimg

url = 'https://res.pandateacher.com/2019-01-12-15-29-33.png'
res = requests.get(url)

#plt.imread()和mpimg.imread()都可以显示

with open('picture.png','wb') as file_project:
    file_project.write(res.content)
plt.imshow(mpimg.imread('picture.png'))
print(mpimg.imread('picture.png'))
plt.show()
# Out:
# [[[0.00392157 0.00784314 0.02352941 1.        ]
#   [0.00392157 0.00784314 0.02352941 1.        ]
#   [0.00392157 0.00784314 0.02352941 1.        ]
#   ...
#   [0.00392157 0.00784314 0.02745098 1.        ]
#   [0.00392157 0.00784314 0.02745098 1.        ]
#   [0.00392157 0.00784314 0.02745098 1.        ]]
#
#  [[0.00392157 0.00784314 0.02352941 1.        ]
#   [0.00392157 0.00784314 0.02352941 1.        ]
#   [0.00392157 0.00784314 0.02352941 1.        ]
#   ...
#   [0.00392157 0.00784314 0.02745098 1.        ]
#   [0.00392157 0.00784314 0.02745098 1.        ]
#   [0.00392157 0.00784314 0.02745098 1.        ]]
#
#  [[0.00392157 0.00784314 0.02352941 1.        ]
#   [0.00392157 0.00784314 0.02352941 1.        ]
#   [0.00392157 0.00784314 0.02352941 1.        ]
#   ...
#   [0.00392157 0.00784314 0.02745098 1.        ]
#   [0.00392157 0.00784314 0.02745098 1.        ]
#   [0.00392157 0.00784314 0.02745098 1.        ]]
#
#  ...
#
#  [[0.33333334 0.4627451  0.41960785 1.        ]
# ...
