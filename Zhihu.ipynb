# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests
import re
import time
#musicid = '107192078'
headers = {           ##这里是为了伪装，即穿马甲
        # 'origin':'https://y.qq.com',
        # 请求来源，本案例中其实是不需要加这个参数的，只是为了演示
        # 'referer':'https://www.zhihu.com/people/zhang-jia-wei/posts?page=1',
        # 请求来源，携带的信息比“origin”更丰富，本案例中其实是不需要加这个参数的，只是为了演示
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
        # 标记了请求从什么设备，什么浏览器上发出
           }
Base_url = 'https://www.zhihu.com/api/v4/members/zhang-jia-wei/articles'
count = 1
page = 1
for i in range(47):
    offset = i*20
    params = {
      'include': 'data[*].comment_count,suggest_edit,is_normal,thumbnail_extra_info,thumbnail,can_comment,comment_permission,admin_closed_comment,content,voteup_count,created,updated,upvoted_followees,voting,review_info,is_labeled,label_info;data[*].author.badge[?(type=best_answerer)].topics',
      'offset': offset,
      'limit': '20',
      'sort_by': 'created'
              }
    ZJQ_json = requests.get(Base_url,headers=headers,params=params)
    ZJQ_json = ZJQ_json.json()
    #print(ZJQ_json['data'])
    data_list = ZJQ_json['data']
    for data in data_list:
        print('第 '+ str(page)+ ' 页 ：')
        print('第 '+ str(count)+ ' 篇文章 ：'+ data['title'])
        print(data['url'])
        print(data['excerpt'])
        print('\n')
        count+=1
    page+=1
    #time.sleep(1)
# Out:
# 第 1 页 ：
# 第 1 篇文章 ：德克vs韦德，宿命对手的全明星谢幕？
# https://zhuanlan.zhihu.com/p/56195809
# 德克和韦德被特招进了2019年全明星。真妙。 先例是有的。比如1991年秋天，魔术师因为众所周知的原因在31岁巅峰期退役了；1992年，他又回来打了全明星：那场大家都捧着他，他也争气，最后时刻连续三个三分球锁定胜局，拿到MVP。德克和韦德，大概是NBA历史上…
#
#
# 第 1 页 ：
# 第 2 篇文章 ：在受伤前，内马尔正踢着人生最好的足球
# https://zhuanlan.zhihu.com/p/55918881
# 2017年夏天，巴黎圣日耳曼四亿哦不对肆意妄为：2.5亿收了内马尔，1.8亿收了姆巴佩。当时看来，一为现在，一为将来。当时25岁的内马尔，可以竞逐当世第三人；当时18岁的姆巴佩，可能在五年后名动天下。2017-18季，巴黎圣日耳曼常以433打天下：内马尔居左，姆…
#
#
# 第 1 页 ：
# 第 3 篇文章 ：让我们记住此刻联盟胜率第四的步行者吧：低调逆潮流的强者
# https://zhuanlan.zhihu.com/p/55649334
# 印第安纳步行者今天第二节失去了奥拉迪普，但还是干掉了多伦多猛龙，送雄鹿上了东部第一。继续胜率东部第三，联盟第四，让我们记住他们吧：因为奥拉迪普这伤一旦重了，这位置可能坐不久了。 大概，步行者已经是全NBA最低调的强队？也难怪。勇士与火箭各有联…
#
#
# 第 1 页 ：
# 第 4 篇文章 ：高手间的惺惺相惜，才是最高级的赞美
# https://zhuanlan.zhihu.com/p/55475764
# 法国人喝红酒，出名的有讲究：海鲜，比如牡蛎，最好配勃艮第白葡萄酒，尤其是沙比利酒——但挑剔的人又说了：不能是太好的沙比利酒，不然矿物味会和海鲜味犯冲。红肉，比如牛肉，最好配红酒；如果香辣料味下得重，则当配西拉葡萄酒。香槟做餐前酒开胃，苏玳…
#
#
# 第 1 页 ：
# 第 5 篇文章 ：嗯哼，Rap，麻辣鸡丝：我们敬爱的赵丽蓉老师
# https://zhuanlan.zhihu.com/p/55390401
# ...

# %%
import requests
import re
import time
import openpyxl 
#引用openpyxl 。
wb = openpyxl.Workbook()
#利用openpyxl.Workbook()函数创建新的workbook（工作薄）对象，就是创建新的空的Excel文件。
sheet = wb.active
#wb.active就是获取这个工作薄的活动表，通常就是第一个工作表。
sheet.title = 'zhihu_passage'
#可以用.title给工作表重命名。现在第一个工作表的名称就会由原来默认的“sheet1”改为"new title"。

row_1= ['序号','页码','作者','标题','摘要','链接']
sheet.append(row_1)

headers = {           ##这里是为了伪装，即穿马甲
        # 'origin':'https://y.qq.com',
        # 请求来源，本案例中其实是不需要加这个参数的，只是为了演示
        # 'referer':'https://www.zhihu.com/people/zhang-jia-wei/posts?page=1',
        # 请求来源，携带的信息比“origin”更丰富，本案例中其实是不需要加这个参数的，只是为了演示
        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
        # 标记了请求从什么设备，什么浏览器上发出
           }
Base_url = 'https://www.zhihu.com/api/v4/members/zhang-jia-wei/articles'
count = 1
page = 1
#offset = 0
#while True :
for i in range (47):
    offset = 20*i
    params = {
      'include': 'data[*].comment_count,suggest_edit,is_normal,thumbnail_extra_info,thumbnail,can_comment,comment_permission,admin_closed_comment,content,voteup_count,created,updated,upvoted_followees,voting,review_info,is_labeled,label_info;data[*].author.badge[?(type=best_answerer)].topics',
      'offset': str(offset),
      'limit': '20',
      'sort_by': 'created'
              }
    ZJQ_json = requests.get(Base_url,headers=headers,params=params)
    ZJQ_json = ZJQ_json.json()
    
    #print(ZJQ_json['data'])
    data_list = ZJQ_json['data']
    for data in data_list:
        print('第 '+ str(page)+ ' 页 ：')
        print('第 '+ str(count)+ ' 篇文章 ：'+ data['title'])
        print('作者：'+ data['author']['name'])
        print(data['url'])
        print(data['excerpt'])
        sheet.append([str(count),str(page),data['author']['name'],data['title'],data['excerpt'],data['url']])
        print('\n')
        count+=1
    #if ZJQ_json['paging']['is_end'] == 'true':  #如果到最后一页了
       # break
    page+=1
#print('循环结束')
wb.save('zhihu.xlsx')
# Out:
# 第 1 页 ：
# 第 1 篇文章 ：德克vs韦德，宿命对手的全明星谢幕？
# 作者：张佳玮
# https://zhuanlan.zhihu.com/p/56195809
# 德克和韦德被特招进了2019年全明星。真妙。 先例是有的。比如1991年秋天，魔术师因为众所周知的原因在31岁巅峰期退役了；1992年，他又回来打了全明星：那场大家都捧着他，他也争气，最后时刻连续三个三分球锁定胜局，拿到MVP。德克和韦德，大概是NBA历史上…
#
#
# 第 1 页 ：
# 第 2 篇文章 ：在受伤前，内马尔正踢着人生最好的足球
# 作者：张佳玮
# https://zhuanlan.zhihu.com/p/55918881
# 2017年夏天，巴黎圣日耳曼四亿哦不对肆意妄为：2.5亿收了内马尔，1.8亿收了姆巴佩。当时看来，一为现在，一为将来。当时25岁的内马尔，可以竞逐当世第三人；当时18岁的姆巴佩，可能在五年后名动天下。2017-18季，巴黎圣日耳曼常以433打天下：内马尔居左，姆…
#
#
# 第 1 页 ：
# 第 3 篇文章 ：让我们记住此刻联盟胜率第四的步行者吧：低调逆潮流的强者
# 作者：张佳玮
# https://zhuanlan.zhihu.com/p/55649334
# 印第安纳步行者今天第二节失去了奥拉迪普，但还是干掉了多伦多猛龙，送雄鹿上了东部第一。继续胜率东部第三，联盟第四，让我们记住他们吧：因为奥拉迪普这伤一旦重了，这位置可能坐不久了。 大概，步行者已经是全NBA最低调的强队？也难怪。勇士与火箭各有联…
#
#
# 第 1 页 ：
# 第 4 篇文章 ：高手间的惺惺相惜，才是最高级的赞美
# 作者：张佳玮
# https://zhuanlan.zhihu.com/p/55475764
# 法国人喝红酒，出名的有讲究：海鲜，比如牡蛎，最好配勃艮第白葡萄酒，尤其是沙比利酒——但挑剔的人又说了：不能是太好的沙比利酒，不然矿物味会和海鲜味犯冲。红肉，比如牛肉，最好配红酒；如果香辣料味下得重，则当配西拉葡萄酒。香槟做餐前酒开胃，苏玳…
#
#
# 第 1 页 ：
# 第 5 篇文章 ：嗯哼，Rap，麻辣鸡丝：我们敬爱的赵丽蓉老师
# 作者：张佳玮
# https://zhuanlan.zhihu.com/p/55390401
# ...

# %%
wb.save('zhihu.xlsx')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-741e5339a6dc> in <module>()
# ----> 1 print(ZJQ_json['paging']['is_end'])
#
# NameError: name 'ZJQ_json' is not defined
