# %%
import requests # 调用requests库
from bs4 import BeautifulSoup # 调用BeautifulSoup库
from gevent import monkey
#从gevent库里导入monkey模块。
monkey.patch_all()
#monkey.patch_all()能把程序变成协作式运行，就是可以帮助程序实现异步。
import gevent,time,requests
#导入gevent、time、requests
from gevent.queue import Queue
#从gevent库里导入queue模块
from Analysis import *
import csv

#start = time.time()
# Out:
# The history saving thread hit an unexpected error (This operation would block forever
# 	Hub: <Hub '' at 0x20ccc7bb630 default pending=0 ref=0 thread_ident=0x3c80>
# 	Handles:
# [HandleState(handle=<cdata 'struct uv_handle_s *' 0x0000020CCB34E698>, type=b'check', watcher=<loop at 0x20ccc408e48 default pending=0 ref=0>, ref=0, active=1, closing=0),
#  HandleState(handle=<cdata 'struct uv_handle_s *' 0x0000020CCA2171F8>, type=b'timer', watcher=<loop at 0x20ccc408e48 default pending=0 ref=0>, ref=0, active=1, closing=0),
#  HandleState(handle=<cdata 'struct uv_handle_s *' 0x0000020CCB34E3D8>, type=b'prepare', watcher=<loop at 0x20ccc408e48 default pending=0 ref=0>, ref=0, active=1, closing=0),
#  HandleState(handle=<cdata 'struct uv_handle_s *' 0x0000020CCB34ECC8>, type=b'check', watcher=<loop at 0x20ccc408e48 default pending=0 ref=0>, ref=1, active=0, closing=0)]).History will not be written to the database.
# D:\Anaconda3\envs\tfcpu\lib\site-packages\gevent\hub.py:154: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
url_menu = 'http://www.boohee.com/food/view_menu'
url_list = ['http://www.boohee.com/food/group/%d'%i for i in range(1,11)]
url_list.append(url_menu)
print(url_list)

#c创建空队列
work = Queue()
for url in url_list:
    work.put_nowait(url)

def crawler():
    with open('HeatQuality_of_food','w', newline = '',encoding = 'gb18030') as csvfile:
        writer=csv.writer(csvfile,dialect='excel')
        writer.writerow(['食物名称','热量'])
        while not work.empty():
            url2 = work.get_nowait()
            for i in range(1,3):
                url_new = url2+'?'+'page={}'.format(i)
                #print(url_new)
                soup = analysis(url_new)
                items = soup.find_all('li',class_='item clearfix')
                for item in items:
                    food_name = item.find('h4').text
                    heat_quality = item.find('p').text
                    print(food_name,heat_quality)
                    writer.writerow([food_name,heat_quality])

tasks_list = []
#定义协程操作
for i in range(11):
    task = gevent.spawn(crawler)
    tasks_list.append(task)
gevent.joinall(tasks_list)
# Out:
# ['http://www.boohee.com/food/group/1', 'http://www.boohee.com/food/group/2', 'http://www.boohee.com/food/group/3', 'http://www.boohee.com/food/group/4', 'http://www.boohee.com/food/group/5', 'http://www.boohee.com/food/group/6', 'http://www.boohee.com/food/group/7', 'http://www.boohee.com/food/group/8', 'http://www.boohee.com/food/group/9', 'http://www.boohee.com/food/group/10', 'http://www.boohee.com/food/view_menu']
# 200
#
# Easy Fun 紫薯营养粥
#  热量：317 大卡(每100克)
#
# 白粥（粳米），又叫稀饭，大米粥，白米粥，米粥
#  热量：46 大卡(每100克)
#
# 白粥（籼米），又叫稀饭，大米粥，白米粥
#  热量：59 大卡(每100克)
#
# 玉米（鲜），又叫苞谷、珍珠米、棒子、玉蜀黍...
#  热量：112 大卡(每100克)
#
# 燕麦片，又叫燕麦
#  热量：338 大卡(每100克)
#
# 面条（生），又叫面
#  热量：301 大卡(每100克)
#
# 面条（煮），又叫面
#  热量：110 大卡(每100克)
#
# 籼米粉，又叫米线、米粉、粉
#  热量：356 大卡(每100克)
#
# 面包
#  热量：313 大卡(每100克)
#
# 红薯，又叫地瓜、番薯、甘薯
#  热量：90 大卡(每100克)
# 200
#
# 小米粥
#  热量：46 大卡(每100克)
#
# 马铃薯，又叫土豆、洋芋、地蛋、山药蛋、洋番薯
#  热量：81 大卡(每100克)
#
# 包子（猪肉馅）
#  热量：227 大卡(每100克)
#
# 米饭，又叫大米饭，饭
#  热量：116 大卡(每100克)
#
# 白薯，又叫山芋、红皮山芋，地瓜、甘薯
#  热量：106 大卡(每100克)
#
# 大米，又叫稻米、米、生米
#  热量：346 大卡(每100克)
#
# 全麦面包，又叫全麦面包、全麦吐司、全麦面包片
#  热量：246 大卡(每100克)
#
# 烙饼
#  热量：259 大卡(每100克)
#
# 花卷
#  热量：214 大卡(每100克)
#
# 油条
#  热量：388 大卡(每100克)
# 200
#
# 鸡蛋，又叫鸡子、鸡卵、蛋
#  热量：144 大卡(每100克)
#
# 猪小排，又叫排骨、猪排
#  热量：278 大卡(每100克)
#
# 鸡（土鸡，家养)
#  热量：124 大卡(每100克)
#
# 鸡（母鸡，一年内）
#  热量：256 大卡(每100克)
#
# 鸡（肉鸡，肥）
#  热量：389 大卡(每100克)
#
# 鸭肉，又叫鸭子、鹜肉、家凫肉
#  热量：240 大卡(每100克)
#
# 猪蹄，又叫猪脚、猪手、猪蹄爪
#  热量：260 大卡(每100克)
#
# 螃蟹（河蟹），又叫螃蟹、毛蟹、稻蟹、中华绒...
#  热量：103 大卡(每100克)
#
# 猪肉(瘦)，又叫猪精肉，瘦肉
#  热量：143 大卡(每100克)
#
# 鸡蛋（煮），又叫水煮蛋，白煮蛋，煮蛋，煮鸡蛋
#  热量：151 大卡(每100克)
# 200
#
# 鸡蛋白（鸡蛋清），又叫鸡蛋白、鸡蛋清、蛋清、蛋白
#  热量：60 大卡(每100克)
#
# 火腿肠
#  热量：212 大卡(每100克)
#
# 鸡胸脯肉，又叫鸡柳肉、鸡里脊肉、鸡胸、鸡胸肉
#  热量：133 大卡(每100克)
#
# 牛肉（牛腩），又叫腹部肉
#  热量：332 大卡(每100克)
#
# 荷包蛋（油煎），又叫荷包蛋、煎蛋、煎荷包蛋...
#  热量：199 大卡(每100克)
#
# 咸鸭蛋，又叫盐蛋、腌蛋、味蛋
#  热量：190 大卡(每100克)
#
# 猪肉(肥瘦)，又叫豕肉、彘肉
#  热量：395 大卡(每100克)
#
# 瓦罐鸡汤（含料）
#  热量：190 大卡(每100克)
#
# 瓦罐鸡汤（无料）
#  热量：27 大卡(每100克)
#
# 猪小排（良杂猪）
#  热量：351 大卡(每100克)
# 200
#
# 酸奶
#  热量：72 大卡(每100毫升)
#
# 牛奶，又叫纯牛奶，牛乳
#  热量：54 大卡(每100毫升)
#
# 奶酪，又叫乳酪、芝士、起司、计司
#  热量：328 大卡(每100克)
#
# 酸奶（中脂）
#  热量：64 大卡(每100毫升)
#
# 酸奶（脱脂）
#  热量：57 大卡(每100毫升)
#
# 脱脂奶粉
#  热量：356 大卡(每100克)
#
# 酸奶（调味）
#  热量：88 大卡(每100毫升)
#
# 光明 鲜牛奶，又叫光明鲜奶、光明牛奶
#  热量：60 大卡(每100毫升)
#
# 酸奶(果料)，又叫果料酸奶
#  热量：67 大卡(每100毫升)
#
# 酸奶（果粒）
#  热量：97 大卡(每100毫升)
# 200
#
# 蒙牛 高钙牛奶
#  热量：59 大卡(每100毫升)
#
# 牛奶（脱脂），又叫脱脂奶，脱脂牛奶，牛乳
#  热量：33 大卡(每100克)
#
# 光明 e+益生菌酸牛奶（原味）220ml ...
#  热量：45 大卡(每100克)
#
# 牛奶（部分脱脂），又叫低脂奶 脱脂奶
#  热量：43 大卡(每100克)
#
# 早餐奶
#  热量：68 大卡(每100克)
#
# 酸奶（高蛋白）
#  热量：62 大卡(每100毫升)
#
# 奶片
#  热量：472 大卡(每100克)
#
# 全脂牛奶粉
#  热量：478 大卡(每100克)
#
# 光明 纯牛奶，又叫光明牛奶
#  热量：66 大卡(每100毫升)
#
# 光明 优倍 高品质鲜牛奶
#  热量：65 大卡(每100毫升)
# 200
#
# 苹果，又叫滔婆、柰、柰子、频婆、平波、天然子
#  热量：53 大卡(每100克)
#
# 大白菜，又叫白菜
#  热量：20 大卡(每100克)
#
# 小白菜，又叫青菜、油白菜、白菜秧、白菜
#  热量：17 大卡(每100克)
#
# 香蕉，又叫蕉子、蕉果、甘蕉
#  热量：93 大卡(每100克)
#
# 番茄，又叫西红柿、洋柿子、狼桃、番李子、金...
#  热量：15 大卡(每100克)
#
# 黄瓜，又叫青瓜
#  热量：16 大卡(每100克)
#
# 西瓜，又叫寒瓜、天生白虎汤、夏瓜、水瓜
#  热量：31 大卡(每100克)
#
# 桃子，又叫桃
#  热量：42 大卡(每100克)
#
# 上海青，又叫青菜，小青菜
#  热量：18 大卡(每100克)
#
# 红富士苹果
#  热量：49 大卡(每100克)
# 200
#
# 橙，又叫橙子、金球、香橙、黄橙、脐橙
#  热量：48 大卡(每100克)
#
# 菜心，又叫白菜薹、薹菜
#  热量：28 大卡(每100克)
#
# 柚子，又叫文旦、香抛、霜柚、臭橙、柚
#  热量：42 大卡(每100克)
#
# 白萝卜，又叫萝卜、莱菔
#  热量：16 大卡(每100克)
#
# 梨，又叫梨子、快果、玉乳、果宗、蜜父、雪梨...
#  热量：51 大卡(每100克)
#
# 花菜，又叫菜花、花椰菜、椰花菜、洋花菜
#  热量：20 大卡(每100克)
#
# 结球甘蓝(紫），又叫紫甘蓝、甘蓝
#  热量：25 大卡(每100克)
#
# 冬枣，又叫枣子，枣
#  热量：113 大卡(每100克)
#
# 猕猴桃，又叫毛桃、藤梨、苌楚、羊桃、毛梨、...
#  热量：61 大卡(每100克)
#
# 南瓜，又叫麦瓜、番瓜、倭瓜、金瓜、伏瓜、饭...
#  热量：23 大卡(每100克)
# 200
#
# 豆浆
#  热量：31 大卡(每100克)
#
# 瓜子（葵花籽），又叫向日葵子、天葵子、葵子...
#  热量：615 大卡(每100克)
#
# 豆浆（甜）
#  热量：34 大卡(每100克)
#
# 豆腐干（白干），又叫豆干、白干
#  热量：197 大卡(每100克)
#
# 黑芝麻，又叫芝麻籽(黑)、胡麻、巨胜
#  热量：559 大卡(每100克)
#
# 豆腐
#  热量：84 大卡(每100克)
#
# 核桃（干），又叫核桃仁、山核桃、胡桃仁、羌...
#  热量：646 大卡(每100克)
#
# 豆腐花，又叫豆腐花、豆花
#  热量：15 大卡(每100克)
#
# 豆腐(南)，又叫嫩豆腐、软豆腐
#  热量：87 大卡(每100克)
#
# 花生（炒）
#  热量：601 大卡(每100克)
# 200
#
# 花生米（生），又叫花生仁（生）
#  热量：574 大卡(每100克)
#
# 花生米（炒），又叫花生仁（炒）
#  热量：589 大卡(每100克)
#
# 豆腐(北)，又叫软玉
#  热量：116 大卡(每100克)
#
# 栗子(熟)，又叫板栗
#  热量：214 大卡(每100克)
#
# 豆腐皮，又叫百片、腐衣、豆皮、油皮
#  热量：447 大卡(每100克)
#
# 豆奶粉
#  热量：423 大卡(每100克)
#
# 豆奶
#  热量：30 大卡(每100克)
#
# 杏仁(烤干，加盐)
#  热量：617 大卡(每100克)
#
# 豆腐脑(带卤)，又叫豆腐花
#  热量：48 大卡(每100克)
#
# 花生（鲜），又叫落花参、番豆、长生果、落地...
#  热量：313 大卡(每100克)
# 200
#
# 拿铁（全脂，无糖），又叫拿铁咖啡
#  热量：44 大卡(每100毫升)
#
# 饮用水，又叫水、自来水
#  热量：0 大卡(每100毫升)
#
# 咖啡粉，又叫速溶咖啡粉
#  热量：218 大卡(每100克)
#
# 麦斯威尔 原味咖啡
#  热量：478 大卡(每100克)
#
# 黑咖啡（液），又叫美式、美式咖啡、澳黑
#  热量：1 大卡(每100毫升)
#
# 矿泉水，又叫水
#  热量：0 大卡(每100毫升)
#
# 啤酒
#  热量：32 大卡(每100毫升)
#
# 天福茗茶 绿茶粉
#  热量：328 大卡(每100克)
#
# 绿茶（茶叶本身），又叫绿茶、茶叶
#  热量：328 大卡(每100克)
#
# 柠檬汁
#  热量：27 大卡(每100毫升)
# 200
#
# 江米酒，又叫糯米酒、甜酒、酒酿、醪糟
#  热量：91 大卡(每100毫升)
#
# 红酒
#  热量：96 大卡(每100毫升)
#
# 茶水，又叫茶
#  热量：0 大卡(每100毫升)
#
# 橙汁饮料（汇源牌）
#  热量：46 大卡(每100毫升)
#
# 光明 藜麦谷物牛奶
#  热量：76 大卡(每100毫升)
#
# 光明 巧克努力 巧克力牛奶饮品
#  热量：87 大卡(每100毫升)
#
# 光明 一只椰子 牛乳饮品
#  热量：58 大卡(每100毫升)
#
# 可口可乐 汽水，又叫可乐
#  热量：43 大卡(每100毫升)
#
# 康宝莱 蛋白混合饮料（巧克力味）
#  热量：370 大卡(每100克)
#
# 私房小厨杏仁粉
#  热量：580 大卡(每100克)
# 200
#
# 色拉油
#  热量：898 大卡(每100克)
#
# 花生油，又叫落花生油、果油、油、食用油
#  热量：899 大卡(每100克)
#
# 豆油，又叫油，食用油
#  热量：899 大卡(每100克)
#
# 混合油(菜+棕)
#  热量：900 大卡(每100克)
#
# 葵花籽油
#  热量：899 大卡(每100克)
#
# 橄榄油
#  热量：899 大卡(每100克)
#
# 菜籽油，又叫菜子油、菜油、油菜籽油、芸苔油...
#  热量：899 大卡(每100克)
#
# 辣椒油，又叫红油、油辣子
#  热量：900 大卡(每100克)
#
# 芝麻油，又叫麻油、芝麻油
#  热量：898 大卡(每100克)
#
# 金龙鱼食用调和油
#  热量：884 大卡(每100克)
# 200
#
# 猪油(板油)，又叫油，食用油，猪网油
#  热量：827 大卡(每100克)
#
# 玉米油
#  热量：895 大卡(每100克)
#
# 猪油(炼)，又叫大油、荤油、猪脂膏
#  热量：897 大卡(每100克)
#
# 香油
#  热量：898 大卡(每100克)
#
# 黄油，又叫白脱油
#  热量：888 大卡(每100克)
#
# 欧丽薇兰特级初榨橄榄油
#  热量：814 大卡(每100克)
#
# 金龙鱼 玉米油
#  热量：884 大卡(每100克)
#
# 胡麻油，又叫亚麻油、亚麻子油、胡麻子油
#  热量：900 大卡(每100克)
#
# 粟米油，又叫玉米胚芽油
#  热量：900 大卡(每100克)
#
# 茶油
#  热量：899 大卡(每100克)
# 200
#
# 蜂蜜，又叫石蜜、石饴、食蜜、蜜、白蜜、白沙...
#  热量：321 大卡(每100克)
#
# 白砂糖，又叫白糖、糖、砂糖、石蜜、白霜糖
#  热量：400 大卡(每100克)
#
# 蜂蜜（槐花）
#  热量：361 大卡(每100克)
#
# 红糖，又叫土红糖、红糖
#  热量：389 大卡(每100克)
#
# 榨菜
#  热量：33 大卡(每100克)
#
# 酱油，又叫豉油、酱汁、豉汁
#  热量：63 大卡(每100克)
#
# 醋，又叫苦酒、淳酢、醯、酢
#  热量：31 大卡(每100克)
#
# 芝麻酱
#  热量：630 大卡(每100克)
#
# 腐乳(红)，又叫南乳、酱豆腐
#  热量：153 大卡(每100克)
#
# 腐乳(白)，又叫酱豆腐、豆腐乳
#  热量：135 大卡(每100克)
# 200
#
# 花生酱
#  热量：600 大卡(每100克)
#
# 红豆沙
#  热量：244 大卡(每100克)
#
# 辣椒酱，又叫辣椒糊
#  热量：36 大卡(每100克)
#
# 味精，又叫味素、味之素
#  热量：268 大卡(每100克)
#
# 榨菜（鱼泉牌）
#  热量：51 大卡(每100克)
#
# 冰糖
#  热量：397 大卡(每100克)
#
# 鸡精
#  热量：195 大卡(每100克)
#
# 番茄酱，又叫茄汁
#  热量：83 大卡(每100克)
#
# 绵白糖
#  热量：396 大卡(每100克)
#
# 食盐，又叫盐、盐巴、咸鹾
#  热量：0 大卡(每100克)
# 200
#
# 饼干
#  热量：435 大卡(每100克)
#
# 蛋糕(黄蛋糕)
#  热量：320 大卡(每100克)
#
# 薄荷松仁粽子糖
#  热量：406 大卡(每100克)
#
# 巧克力，又叫朱古力
#  热量：589 大卡(每100克)
#
# 冰淇淋，又叫冰激凌、雪糕
#  热量：127 大卡(每100克)
#
# 红薯干，又叫地瓜干，甘薯干
#  热量：338 大卡(每100克)
#
# 培根汉堡（夹熏肉，奶酪，加调料酱）
#  热量：311 大卡(每100克)
#
# 绿豆饼（少糖少油）
#  热量：122 大卡(每100克)
#
# 苏打饼干
#  热量：408 大卡(每100克)
#
# 麻花
#  热量：527 大卡(每100克)
# 200
#
# 奶油蛋糕
#  热量：379 大卡(每100克)
#
# 佳梅 真之话梅
#  热量：180 大卡(每100克)
#
# 月饼(豆沙)
#  热量：411 大卡(每100克)
#
# 山楂果丹皮
#  热量：326 大卡(每100克)
#
# 蛋糕
#  热量：348 大卡(每100克)
#
# 沙琪玛蛋酥
#  热量：506 大卡(每100克)
#
# 单层汉堡（单层肉饼，无调料酱）
#  热量：316 大卡(每100克)
#
# 绿豆糕
#  热量：351 大卡(每100克)
#
# 西式蛋糕
#  热量：316 大卡(每100克)
#
# 野澤 猴肉（腊梅味）
#  热量：295 大卡(每100克)
# 200
#
# 麦当劳 麦香鸡
#  热量：283 大卡(每100克)
#
# 油面筋，又叫面筋泡、油炸生筋
#  热量：492 大卡(每100克)
#
# 千亿朵星光 益生菌含片(酸甜芒果味)
#  热量：379 大卡(每100克)
#
# Easy Fun 阿胶糕（玫瑰型）
#  热量：426 大卡(每100克)
#
# Easy Fun 益生元龟苓膏
#  热量：39 大卡(每100克)
#
# 枸杞，又叫甘杞、贡杞、枸杞子、红耳坠、苟起...
#  热量：258 大卡(每100克)
#
# 陈皮，又叫橘皮、贵老、红皮、黄橘皮、广橘皮...
#  热量：319 大卡(每100克)
#
# 栝楼根粉，又叫栝楼粉、蒌粉、天花粉
#  热量：397 大卡(每100克)
#
# 葛根，又叫野葛、鹿霍、黄斤、鸡齐根、干葛、...
#  热量：181 大卡(每100克)
#
# 阿拉斯加 康力士螺旋藻复合片
#  热量：335 大卡(每100克)
# 200
#
# 美国GBN进口蛋白质粉
#  热量：407 大卡(每100克)
#
# 花粉（油松），又叫松花粉
#  热量：398 大卡(每100克)
#
# 阿拉斯加 康力士乳清蛋白粉（香草味）
#  热量：395 大卡(每100克)
#
# 菊花（干），又叫怀菊花、节华、日精、女节、...
#  热量：242 大卡(每100克)
#
# 花粉（荞麦）
#  热量：353 大卡(每100克)
#
# 纽崔莱 果蔬纤维素嚼片
#  热量：488 大卡(每100克)
#
# 阿拉斯加 康力士玫瑰果提取物复合片
#  热量：402 大卡(每100克)
#
# 蚕蛹
#  热量：230 大卡(每100克)
#
# 金日 高营养蛋白质粉
#  热量：197 大卡(每100克)
#
# 米粉（雀巢）
#  热量：376 大卡(每100克)
# 200
#
# 炒青菜，又叫清炒青菜;素炒青菜
#  热量：41 大卡(每100克)
#
# 番茄炒蛋，又叫番茄炒鸡蛋、西红柿炒蛋、西红...
#  热量：87 大卡(每100克)
#
# 吐司面包，又叫吐司、白吐司、面包片、切片面包
#  热量：278 大卡(每100克)
#
# 绿豆汤
#  热量：46 大卡(每100克)
#
# 素炒小白菜
#  热量：46 大卡(每100克)
#
# 烧茄子
#  热量：74 大卡(每100克)
#
# 绿豆粥
#  热量：48 大卡(每100克)
#
# 香菇青菜包，又叫菜包、香菇菜包、菜包子、素...
#  热量：166 大卡(每100克)
#
# 牛肉面，又叫兰州牛肉面，兰州拉面
#  热量：119 大卡(每100克)
#
# 蛋炒饭
#  热量：154 大卡(每100克)
# 200
#
# 红烧鳓鱼
#  热量：216 大卡(每100克)
#
# 盐水虾
#  热量：92 大卡(每100克)
#
# 炒绿豆芽
#  热量：30 大卡(每100克)
#
# 葱油饼，又叫葱花饼
#  热量：259 大卡(每100克)
#
# 清炒西葫芦
#  热量：50 大卡(每100克)
#
# 西红柿鸡蛋面，又叫番茄蛋面
#  热量：97 大卡(每100克)
#
# 酸辣土豆丝
#  热量：122 大卡(每100克)
#
# 红烧肉
#  热量：470 大卡(每100克)
#
# 韭菜包子
#  热量：171 大卡(每100克)
#
# 卤蛋，又叫卤鸡蛋
#  热量：148 大卡(每100克)
