# %%
#-*- coding-8 -*-
import requests
import lxml
import sys
from bs4 import BeautifulSoup
import xlwt
import time
import urllib
 
def craw(url,key_word,x):
    User_Agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:56.0) Gecko/20100101 Firefox/56.0'
#    if x == 0:
#        re = 'http://www.qichacha.com/search?key='+key_word
#    else:
#        re = 'https://www.qichacha.com/search?key={}#p:{}&'.format(key_word,x-1)
    re = r'https://www.qcc.com/search?key='+key_word
    headers = {
            'Host':'www.qcc.com',
            'Connection': 'keep-alive',
            'Accept':r'text/html, */*; q=0.01',
            'X-Requested-With': 'XMLHttpRequest',
            'User-Agent':r'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
            'Referer': re,
            'Accept-Encoding':'gzip, deflate, br',
            'Accept-Language':'zh-CN,zh;q=0.9',
            'Cookie':r'QCCSESSID=2ejptsufcggo8muktorundmee0; zg_did=%7B%22did%22%3A%20%22175ac40375f3b5-08abe758c88cd5-333376b-144000-175ac403760b8f%22%7D; UM_distinctid=175ac40378f5b4-0287ca5c2a6b54-333376b-144000-175ac40379093; hasShow=1; _uab_collina=160491269125971001658956; CNZZDATA1254842228=1663184996-1604907305-https%253A%252F%252Fwww.baidu.com%252F%7C1604912702; zg_5068e513cb8449879f83e2a7142b20a6=%7B%22sid%22%3A%201604912857374%2C%22updated%22%3A%201604912858382%2C%22info%22%3A%201604912857378%2C%22superProperty%22%3A%20%22%7B%5C%22%E5%BA%94%E7%94%A8%E5%90%8D%E7%A7%B0%5C%22%3A%20%5C%22%E6%8B%9B%E6%8A%95%E6%A0%87WEB%E7%AB%AF%5C%22%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22www.qcc.com%22%7D; acw_tc=79c2079516049158225346317e3287aa3fec43955d214af2f7a9a69bc4; zg_de1d1a35bfa24ce29bbf2c7eb17e6c4f=%7B%22sid%22%3A%201604915841373%2C%22updated%22%3A%201604916146738%2C%22info%22%3A%201604912691047%2C%22superProperty%22%3A%20%22%7B%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22www.qcc.com%22%2C%22zs%22%3A%200%2C%22sc%22%3A%200%2C%22cuid%22%3A%20%22be68457553795d939b1ed60b4bba980d%22%7D'
    }
 
    try:
        response = requests.get(url,headers = headers)
        if response.status_code != 200:
            response.encoding = 'utf-8'
            print(response.status_code)
            print('ERROR')    
        soup = BeautifulSoup(response.text,'lxml')
        #print(soup)
    except Exception:
        print('请求都不让，这企查查是想逆天吗？？？')
    try:
        com_all_info = soup.find_all(class_='m_srchList')[0].tbody
        print(com_all_info)
        com_all_info_array = com_all_info.select('tr')
        print('开始爬取数据，请勿打开excel')
        for i in range(0,len(com_all_info_array)):
#            try:
                temp_g_name = com_all_info_array[i].select('td')[2].select('.ma_h1')[0].text    #获取公司名
                temp_g_tag = com_all_info_array[i].select('td')[2].select('.search-tags')[0].text    #获取公司标签
                temp_r_name = com_all_info_array[i].select('td')[2].select('p')[0].a.text    #获取法人名
                temp_g_money = com_all_info_array[i].select('td')[2].select('p')[0].select('span')[0].text.strip('注册资本：')    #获取注册资本
                temp_g_date = com_all_info_array[i].select('td')[2].select('p')[0].select('span')[1].text.strip('成立日期：')    #获取公司注册时间
                temp_r_email = com_all_info_array[i].select('td')[2].select('p')[1].text.split('\n')[1].strip().strip('邮箱：')    #获取法人Email
                temp_r_phone = com_all_info_array[i].select('td')[2].select('p')[1].select('.m-l')[0].text.strip('电话：')    #获取法人手机号
                temp_g_addr = com_all_info_array[i].select('td')[2].select('p')[2].text.strip().strip('地址：')    #获取公司地址
                temp_g_state = com_all_info_array[i].select('td')[3].select('.nstatus.text-success-lt.m-l-xs')[0].text.strip()  #获取公司状态
                 
                g_name_list.append(temp_g_name)
                g_tag_list.append(temp_g_tag)
                r_name_list.append(temp_r_name)
                g_money_list.append(temp_g_money)
                g_date_list.append(temp_g_date)
                r_email_list.append(temp_r_email)
                r_phone_list.append(temp_r_phone)
                g_addr_list.append(temp_g_addr)
                g_state_list.append(temp_g_state)
                 
#            except Exception:
#                print('错误！')
    except Exception:
        print('好像被拒绝访问了呢...请稍后再试叭...')
         
if __name__ == '__main__':
    global g_name_list
    global g_tag_list
    global r_name_list
    global g_money_list
    global g_date_list
    global r_email_list
    global r_phone_list
    global g_addr_list
    global g_state_list
     
    g_name_list=[]
    g_tag_list=[]
    r_name_list=[]
    g_money_list=[]
    g_date_list=[]
    r_email_list=[]
    r_phone_list=[]
    g_addr_list=[]
    g_state_list=[]
 
    key_word = input('请输入您想搜索的关键词：')
    num = int(input('请输入您想检索的次数：'))+1
    sleep_time = int(input('请输入每次检索延时的秒数：'))
     
    key_word = urllib.parse.quote(key_word)
     
    print('正在搜索，请稍后')
     
    for x in range(1,num):
        url = r'https://www.qcc.com/search_index?key={}&ajaxflag=1&p={}&'.format(key_word,x)
        s1 = craw(url,key_word,x)
        time.sleep(sleep_time)
    workbook = xlwt.Workbook()
    #创建sheet对象，新建sheet
    sheet1 = workbook.add_sheet('企查查数据', cell_overwrite_ok=True)
    #---设置excel样式---
    #初始化样式
    style = xlwt.XFStyle()
    #创建字体样式
    font = xlwt.Font()
    font.name = '仿宋'
#    font.bold = True #加粗
    #设置字体
    style.font = font
    #使用样式写入数据
    print('正在存储数据，请勿打开excel')
    #向sheet中写入数据
    name_list = ['公司名字','公司标签','法定法人','注册资本','成立日期','法人邮箱','法人电话','公司地址','公司状态']
    for cc in range(0,len(name_list)):
        sheet1.write(0,cc,name_list[cc],style)
    for i in range(0,len(g_name_list)):
        print(g_name_list[i])
        sheet1.write(i+1,0,g_name_list[i],style)#公司名字
        sheet1.write(i+1,1,g_tag_list[i],style)#公司标签
        sheet1.write(i+1,2,r_name_list[i],style)#法定法人
        sheet1.write(i+1,3,g_money_list[i],style)#注册资本
        sheet1.write(i+1,4,g_date_list[i],style)#成立日期
        sheet1.write(i+1,5,r_email_list[i],style)#法人邮箱
        sheet1.write(i+1,6,r_phone_list[i],style)#法人电话
        sheet1.write(i+1,7,g_addr_list[i],style)#公司地址
        sheet1.write(i+1,8,g_state_list[i],style)#公司状态
    #保存excel文件，有同名的直接覆盖
    workbook.save(r"D:\wyy-qcc-"+time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime()) +".xls")
    print('保存完毕~')
# Out:
# 请输入您想搜索的关键词：上海璐英实业有限公司
# 请输入您想检索的次数：1
# 请输入每次检索延时的秒数：1
# 正在搜索，请稍后
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-08be82495f9e> in <module>()
# ----> 1 com_all_info = soup.find_all(class_='m_srchList')[0].tbody
#
# NameError: name 'soup' is not defined

# %%
url= 'https://www.qcc.com/firm/9bf0f3582ad7f18351e07202fd4097c1.html'

# %%
headers = {
            'Host':'www.qcc.com',
            'Connection': 'keep-alive',
            'Accept':r'text/html, */*; q=0.01',
            'X-Requested-With': 'XMLHttpRequest',
            'User-Agent':r'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
            'Accept-Encoding':'gzip, deflate, br',
            'Accept-Language':'zh-CN,zh;q=0.9',
            'Cookie':r'QCCSESSID=2ejptsufcggo8muktorundmee0; zg_did=%7B%22did%22%3A%20%22175ac40375f3b5-08abe758c88cd5-333376b-144000-175ac403760b8f%22%7D; UM_distinctid=175ac40378f5b4-0287ca5c2a6b54-333376b-144000-175ac40379093; hasShow=1; _uab_collina=160491269125971001658956; CNZZDATA1254842228=1663184996-1604907305-https%253A%252F%252Fwww.baidu.com%252F%7C1604912702; zg_5068e513cb8449879f83e2a7142b20a6=%7B%22sid%22%3A%201604912857374%2C%22updated%22%3A%201604912858382%2C%22info%22%3A%201604912857378%2C%22superProperty%22%3A%20%22%7B%5C%22%E5%BA%94%E7%94%A8%E5%90%8D%E7%A7%B0%5C%22%3A%20%5C%22%E6%8B%9B%E6%8A%95%E6%A0%87WEB%E7%AB%AF%5C%22%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22www.qcc.com%22%7D; acw_tc=79c2079516049158225346317e3287aa3fec43955d214af2f7a9a69bc4; zg_de1d1a35bfa24ce29bbf2c7eb17e6c4f=%7B%22sid%22%3A%201604915841373%2C%22updated%22%3A%201604916146738%2C%22info%22%3A%201604912691047%2C%22superProperty%22%3A%20%22%7B%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22www.qcc.com%22%2C%22zs%22%3A%200%2C%22sc%22%3A%200%2C%22cuid%22%3A%20%22be68457553795d939b1ed60b4bba980d%22%7D'
    }
 
  
response = requests.get(url,headers = headers)
soup = BeautifulSoup(response.text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.find(id='Cominfo').find_all('tr')[4].find_all('td')[1].text.strip())
# Out:
# 有限责任公司（自然人投资或控股）

# %%
print(soup.find(id='Cominfo').find_all('tr')[-2].find_all('td')[1].text.strip().split("\n")[0])
# Out:
# 上海市松江区泗泾镇文化路298号

# %%
#-*- coding-8 -*-
import requests
import lxml
import sys
from bs4 import BeautifulSoup
import pandas as pd
import sys
import time
import urllib
import openpyxl
    
def company_data_frame(filename):
    df = pd.read_excel(filename)
    col_name = df.columns.values.tolist()[0]
    return df[col_name]

def get_company_info(href):
    url = 'https://www.qcc.com'+href
    
    headers = {
                'Host':'www.qcc.com',
                'Connection': 'keep-alive',
                'Accept':r'text/html, */*; q=0.01',
                'X-Requested-With': 'XMLHttpRequest',
                'User-Agent':r'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
                'Accept-Encoding':'gzip, deflate, br',
                'Accept-Language':'zh-CN,zh;q=0.9',
                'Cookie':r'QCCSESSID=2ejptsufcggo8muktorundmee0; zg_did=%7B%22did%22%3A%20%22175ac40375f3b5-08abe758c88cd5-333376b-144000-175ac403760b8f%22%7D; UM_distinctid=175ac40378f5b4-0287ca5c2a6b54-333376b-144000-175ac40379093; hasShow=1; _uab_collina=160491269125971001658956; CNZZDATA1254842228=1663184996-1604907305-https%253A%252F%252Fwww.baidu.com%252F%7C1604912702; zg_5068e513cb8449879f83e2a7142b20a6=%7B%22sid%22%3A%201604912857374%2C%22updated%22%3A%201604912858382%2C%22info%22%3A%201604912857378%2C%22superProperty%22%3A%20%22%7B%5C%22%E5%BA%94%E7%94%A8%E5%90%8D%E7%A7%B0%5C%22%3A%20%5C%22%E6%8B%9B%E6%8A%95%E6%A0%87WEB%E7%AB%AF%5C%22%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22www.qcc.com%22%7D; acw_tc=79c2079516049158225346317e3287aa3fec43955d214af2f7a9a69bc4; zg_de1d1a35bfa24ce29bbf2c7eb17e6c4f=%7B%22sid%22%3A%201604915841373%2C%22updated%22%3A%201604916146738%2C%22info%22%3A%201604912691047%2C%22superProperty%22%3A%20%22%7B%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22www.qcc.com%22%2C%22zs%22%3A%200%2C%22sc%22%3A%200%2C%22cuid%22%3A%20%22be68457553795d939b1ed60b4bba980d%22%7D'
        }
    response = requests.get(url,headers = headers)
    soup = BeautifulSoup(response.text,'lxml')
    try:
        company_name = soup.find('h1').text
        company_type = soup.find(id='Cominfo').find_all('tr')[4].find_all('td')[1].text.strip()
        company_address = soup.find(id='Cominfo').find_all('tr')[-2].find_all('td')[1].text.strip().split("\n")[0]
        return [company_name,company_type,company_address]
    except Exception:
        return None
    

def craw(url,key_word):
    User_Agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:56.0) Gecko/20100101 Firefox/56.0'
    re = r'https://www.qcc.com/search?key='+key_word
    headers = {
            'Host':'www.qcc.com',
            'Connection': 'keep-alive',
            'Accept':r'text/html, */*; q=0.01',
            'X-Requested-With': 'XMLHttpRequest',
            'User-Agent':r'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
            'Referer': re,
            'Accept-Encoding':'gzip, deflate, br',
            'Accept-Language':'zh-CN,zh;q=0.9',
            'Cookie':r'QCCSESSID=2ejptsufcggo8muktorundmee0; zg_did=%7B%22did%22%3A%20%22175ac40375f3b5-08abe758c88cd5-333376b-144000-175ac403760b8f%22%7D; UM_distinctid=175ac40378f5b4-0287ca5c2a6b54-333376b-144000-175ac40379093; hasShow=1; _uab_collina=160491269125971001658956; CNZZDATA1254842228=1663184996-1604907305-https%253A%252F%252Fwww.baidu.com%252F%7C1604912702; zg_5068e513cb8449879f83e2a7142b20a6=%7B%22sid%22%3A%201604912857374%2C%22updated%22%3A%201604912858382%2C%22info%22%3A%201604912857378%2C%22superProperty%22%3A%20%22%7B%5C%22%E5%BA%94%E7%94%A8%E5%90%8D%E7%A7%B0%5C%22%3A%20%5C%22%E6%8B%9B%E6%8A%95%E6%A0%87WEB%E7%AB%AF%5C%22%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22www.qcc.com%22%7D; acw_tc=79c2079516049158225346317e3287aa3fec43955d214af2f7a9a69bc4; zg_de1d1a35bfa24ce29bbf2c7eb17e6c4f=%7B%22sid%22%3A%201604915841373%2C%22updated%22%3A%201604916146738%2C%22info%22%3A%201604912691047%2C%22superProperty%22%3A%20%22%7B%7D%22%2C%22platform%22%3A%20%22%7B%7D%22%2C%22utm%22%3A%20%22%7B%7D%22%2C%22referrerDomain%22%3A%20%22www.qcc.com%22%2C%22zs%22%3A%200%2C%22sc%22%3A%200%2C%22cuid%22%3A%20%22be68457553795d939b1ed60b4bba980d%22%7D'
    }
 
    try:
        response = requests.get(url,headers = headers)
        if response.status_code != 200:
            response.encoding = 'utf-8'
            print(response.status_code)
            print('ERROR')    
        soup = BeautifulSoup(response.text,'lxml')
        #print(soup)
    except Exception:
        print('请求都不让，这企查查是想逆天吗？？？')
    try:
        href = soup.find_all(class_='ma_h1')[0]['href']
        print('开始爬取数据，请勿打开excel')
        return href
        
    except Exception:
        print('好像被拒绝访问了呢...请稍后再试叭...')
        print(str(Exception))
         
if __name__ == '__main__':
   
    filename = '公司列表.xlsx'
    start_index = int(input("请输入起始索引"))-2
    end_index = int(input("请输入终止索引"))-2
    if start_index<0 or end_index<0:
        print("请根据Excel中公司列表的索引输入")
        sys.exit()
    df = company_data_frame(filename)
    num = len(df)
    sleep_time = 5
    column_name = ['企业名称', '企业类型 ','企业地址', '爬取状态']
    wb = openpyxl.Workbook()
    #利用openpyxl.Workbook()函数创建新的workbook（工作薄）对象，就是创建新的空的Excel文件。
    sheet = wb.active
    #wb.active就是获取这个工作薄的活动表，通常就是第一个工作表。
    sheet.title = 'new title'
    #可以用.title给工作表重命名。现在第一个工作表的名称就会由原来默认的“sheet1”改为"new title"。
    sheet.append(column_name)
    for i in range(start_index,end_index):
        key_word2 = df[i]
        key_word = urllib.parse.quote(key_word2)

        print('正在搜索，请稍后')


        url = r'https://www.qcc.com/search_index?key={}'.format(key_word)
        href= craw(url,key_word)
        if not href:
            sheet.append(["xxxxx","xxxxx","xxxxx",key_word2])
            continue
        line = get_company_info(href)
        if not line:
            sheet.append(["xxxxx","xxxxx","xxxxx",key_word2])
            continue
        if line[0]==key_word2:
            state = '正确'
        else:
            state = key_word2
        
        line.append(state)
        print(line)
        sheet.append(line)
        time.sleep(sleep_time)
        print('正在存储数据，请勿打开excel')
        #向sheet中写入数据

        print('保存完毕~')
    wb.save('qcc_spider_{}_{}.xlsx'.format(str(start_index),str(end_index)))
# Out:
# 请输入起始索引0
# 请输入终止索引1
# 请根据Excel中公司列表的索引输入
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# D:\Anaconda3\envs\tfcpu\lib\site-packages\IPython\core\interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
wb = openpyxl.load_workbook('公司列表.xlsx')
sheet = wb['new title']
#先获取表
sheetname = wb.sheetnames
print(sheetname)
A1_cell = sheet['A1']
A1_value = A1_cell.value
print(A1_value)

# %%
filename = '公司列表.xlsx'
def company_data_frame(filename):
    df = pd.read_excel(filename)
    col_name = df.columns.values.tolist()[0]
    print(col_name)
    return df[col_name]
df= company_data_frame(filename)
# Out:
# 公司名称

# %%
print(df)
# Out:
# 0                     广西柳州钢铁集团有限公司
# 1                    湛江港(集团)股份有限公司
# 2                       长安福特汽车有限公司
# 3                    深圳市东部公共交通有限公司
# 4                      一汽-大众汽车有限公司
# 5                         宝钢发展有限公司
# 6                   上汽通用五菱汽车股份有限公司
# 7             中国石油天然气股份有限公司大庆炼化分公司
# 8                  大庆油田有限责任公司第四采油厂
# 9                  大庆油田有限责任公司第一采油厂
# 10                    玖龙纸业(东莞)有限公司
# 11                        武汉钢铁有限公司
# 12                    捷普科技(成都)有限公司
# 13               深圳巴士集团股份有限公司第三分公司
# 14                      中航飞机股份有限公司
# 15                成都飞机工业（集团）有限责任公司
# 16                大庆油田有限责任公司天然气分公司
# 17             深圳巴士集团股份有限公司公共汽车分公司
# 18                    重庆长安汽车股份有限公司
# 19                 大庆油田有限责任公司第七采油厂
# 20               大庆油田有限责任公司井下作业分公司
# 21           大庆油田有限责任公司钻探工程公司钻井二公司
# 22                      上汽大众汽车有限公司
# 23                中国石油乌鲁木齐石油化工有限公司
# 24                  中国邮政集团公司四川省分公司
# 25                 重庆市轨道交通（集团）有限公司
# 26                 大庆油田有限责任公司第二采油厂
# ...

# %%
print(len(df))
print(df["公司名称"][0])
# Out:
# 50611
# 广西柳州钢铁集团有限公司

# %%
df.columns.values.tolist()
# Out:
# ['公司名称']
